# %%
# Built-in/Generic Imports
import os
import sys
#

# Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import mglearn.plots
#

# Modules
from io import StringIO
from sklearn import tree
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_breast_cancer
from sklearn.tree import DecisionTreeClassifier
from sklearn.datasets import make_blobs
from sklearn.svm import LinearSVC
from sklearn.svm import SVC
from sklearn.metrics import classification_report,confusion_matrix
from sklearn.metrics import precision_score
#

#Suppress scientific notation
np.set_printoptions(suppress=True)

# %%
#import file for dataset
budgetdata = pd.read_csv('R:/budget_data/stmt_01292018.csv',skiprows=6) 
budgetdata.fillna(0)
# Out:
#            Date                                        Description  Amount  \
# 0    12/28/2017                 Beginning balance as of 12/28/2017    0.00
# 1    12/29/2017  BKOFAMERICA ATM 12/29 #000007737 DEPOSIT LAKE ...   20.00
# 2    01/02/2018  Online Banking Transfer Conf# 501d2de25; MARSH...  250.00
# 3    01/02/2018      CALVARY CHURCH 12/27 PURCHASE 972-261-1919 TX  -96.15
# 4    01/02/2018  AMAZON VIDEO ON DEMAND 12/28 PURCHASE 888-802-...   -6.48
# 5    01/02/2018  AMAZON SERVICES-KINDLE 12/29 PURCHASE 888-802-...   -5.40
# 6    01/02/2018          Audible US 12/29 PURCHASE 888-283-5051 NJ  -14.06
# 7    01/02/2018  AMAZON SERVICES-KINDLE 12/30 PURCHASE 888-802-...  -12.98
# 8    01/02/2018    TARGET 00022434 12/29 PURCHASE GRAND PRAIRIE TX   -4.36
# 9    01/02/2018      CALVARY CHURCH 12/30 PURCHASE 972-261-1919 TX  -20.00
# 10   01/02/2018   PAPA JOHN'S 00741 12/31 PURCHASE 972-642-3030 TX  -16.23
# 11   01/02/2018                         BANKAMERICARD Bill Payment -305.00
# 12   01/02/2018  MidSouth Bank DES:FITRANSFER ID:XXXXX0047222 I... -200.00
# 13   01/02/2018  PAYPAL DES:INST XFER ID:HUMBLEBUNDL INDN:ANDRE...  -18.00
# 14   01/02/2018  PAYPAL DES:INST XFER ID:STEAM GAMES INDN:ANDRE...  -10.60
# 15   01/02/2018  PAYPAL DES:INST XFER ID:PATREON INDN:ANDREW MA...   -4.00
# 16   01/02/2018  KEEP THE CHANGE TRANSFER TO ACCT 6621 FOR 01/0...   -4.34
# 17   01/03/2018  DELI MANAGEMENT DES:DIRECT DEP ID:DMI4796 INDN...  593.53
# 18   01/03/2018      CBS ALL ACCESS 01/01 PURCHASE 888-274-5343 CA   -6.47
# 19   01/03/2018  GasBuddy DES:GasBuddy ID: ILVLGR5V INDN:ANDREW...   -9.78
# 20   01/03/2018  KEEP THE CHANGE TRANSFER TO ACCT 6621 FOR 01/0...   -0.53
# 21   01/04/2018   MCDONALD'S F6059 01/02 PURCHASE GRAND PRAIRIE TX   -9.06
# 22   01/04/2018  KEEP THE CHANGE TRANSFER TO ACCT 6621 FOR 01/0...   -0.94
# 23   01/05/2018      CALVARY CHURCH 01/03 PURCHASE 972-261-1919 TX  -96.15
# 24   01/05/2018  KEEP THE CHANGE TRANSFER TO ACCT 6621 FOR 01/0...   -0.85
# 25   01/08/2018   MCDONALD'S F6059 01/04 PURCHASE GRAND PRAIRIE TX   -5.81
# 26   01/08/2018     POPEYE'S #4552 01/05 PURCHASE GRAND PRAIRIE TX   -4.97
# 27   01/08/2018  GOOGLE *PROJECT FI 01/06 PURCHASE g.co/helppay...  -36.49
# 28   01/08/2018  AMAZON DIGITAL SVCS AMZ 01/06 PURCHASE 888-802...  -16.23
# 29   01/08/2018      CALVARY CHURCH 01/06 PURCHASE 972-261-1919 TX  -10.00
# ..          ...                                                ...     ...
# 72   01/22/2018    TARGET 00022434 01/19 PURCHASE GRAND PRAIRIE TX  -11.68
# 73   01/22/2018  HLU*Hulu 97077428-U 01/19 PURCHASE HULU.COM/BI...  -12.95
# 74   01/22/2018      CALVARY CHURCH 01/20 PURCHASE 972-261-1919 TX  -10.00
# 75   01/22/2018  AMAZON.COM AMZN.COM/BIL 01/21 PURCHASE AMZN.CO...  -12.87
# 76   01/22/2018  KEEP THE CHANGE TRANSFER TO ACCT 6621 FOR 01/2...   -0.95
# 77   01/23/2018  DELI MANAGEMENT DES:DIRECT DEP ID:DMI4796 INDN...  593.44
# 78   01/23/2018  PAYPAL DES:TRANSFER ID:5L4J2AD949TRS INDN:ANDR...   31.76
# 79   01/23/2018          Audible US 01/21 PURCHASE 888-283-5051 NJ   -5.36
# 80   01/23/2018    TARGET 00022434 01/22 PURCHASE GRAND PRAIRIE TX  -16.34
# 81   01/23/2018  KEEP THE CHANGE TRANSFER TO ACCT 6621 FOR 01/2...   -1.30
# 82   01/24/2018  AMAZON.COM AMZN.COM/BIL 01/21 PURCHASE AMZN.CO...  -10.60
# 83   01/24/2018  AMAZON MKTPLACE PMTS WW 01/21 PURCHASE WWW.AMA...  -12.23
# 84   01/24/2018  AMAZON.COM AMZN.COM/BIL 01/21 PURCHASE AMZN.CO...   -9.14
# 85   01/24/2018  AMAZON.COM AMZN.COM/BIL 01/21 PURCHASE AMZN.CO...  -11.01
# 86   01/24/2018  AMAZON.COM AMZN.COM/BIL 01/21 PURCHASE AMZN.CO...   -5.88
# 87   01/24/2018             Audible 01/24 PURCHASE adbl.co/bill NJ  -24.84
# 88   01/24/2018  SN(888)296-4290 DES:SMART NOTE ID:XXXXX0904407... -201.28
# 89   01/24/2018  KEEP THE CHANGE TRANSFER TO ACCT 6621 FOR 01/2...   -3.30
# 90   01/25/2018  Online Banking transfer from SAV 6621 Confirma...   34.35
# 91   01/25/2018      CALVARY CHURCH 01/23 PURCHASE 972-261-1919 TX  -96.15
# 92   01/25/2018  MidSouth Bank DES:FITRANSFER ID:XXXXX0047222 I... -210.00
# 93   01/25/2018  KEEP THE CHANGE TRANSFER TO ACCT 6621 FOR 01/2...   -0.85
# 94   01/26/2018      CALVARY CHURCH 01/24 PURCHASE 972-261-1919 TX  -10.00
# 95   01/26/2018  ONSTAR DATA PLAN - AT&T 01/25 PURCHASE WWW.ATT...  -20.07
# 96   01/26/2018  PAYPAL DES:INST XFER ID:NETFLIX.COM INDN:ANDRE...  -11.90
# 97   01/26/2018  KEEP THE CHANGE TRANSFER TO ACCT 6621 FOR 01/2...   -0.93
# 98   01/29/2018    TARGET 00022434 01/26 PURCHASE GRAND PRAIRIE TX  -13.82
# 99   01/29/2018      CALVARY CHURCH 01/27 PURCHASE 972-261-1919 TX  -10.00
# 100  01/29/2018    TARGET 00022434 01/28 PURCHASE GRAND PRAIRIE TX  -10.27
# 101  01/29/2018  KEEP THE CHANGE TRANSFER TO ACCT 6621 FOR 01/2...   -0.91
#
#      Running Bal.
# 0          496.47
# 1          516.47
# 2          766.47
# 3          670.32
# 4          663.84
# 5          658.44
# 6          644.38
# 7          631.40
# 8          627.04
# 9          607.04
# 10         590.81
# 11         285.81
# 12          85.81
# 13          67.81
# 14          57.21
# 15          53.21
# 16          48.87
# 17         642.40
# 18         635.93
# 19         626.15
# 20         625.62
# 21         616.56
# 22         615.62
# 23         519.47
# 24         518.62
# 25         512.81
# 26         507.84
# 27         471.35
# 28         455.12
# 29         445.12
# ..            ...
# 72         117.37
# 73         104.42
# 74          94.42
# 75          81.55
# 76          80.60
# 77         674.04
# 78         705.80
# 79         700.44
# 80         684.10
# 81         682.80
# 82         672.20
# 83         659.97
# 84         650.83
# 85         639.82
# 86         633.94
# 87         609.10
# 88         407.82
# 89         404.52
# 90         438.87
# 91         342.72
# 92         132.72
# 93         131.87
# 94         121.87
# 95         101.80
# 96          89.90
# 97          88.97
# 98          75.15
# 99          65.15
# 100         54.88
# 101         53.97
#
# [102 rows x 4 columns]
